# %% [markdown]
# # HW 5 Cecily Wang Spring 2024 BA 476

# %% [markdown]
# The final homework is a kaggle competition. You will predict whether loan applicants are repaid or not. The target is binary (1 represents default) and you will be asked for probabilistic predictions, i.e. you have to predict the probability of default. Submissions will be evaluated using Brier scores, and your grade will depend on the accuracy of your predictions.
#
# This dataset is synthetically generated from a well-known public dataset (available here). The dataset used for the competition is (obviously) not identical to the original; you are welcome to use the original in whatever way you want.
#
# **Goal**: Your goal is to predict the probability a loan applicant defaults on the loan (outcome=1) or repays it (outcome=0). A predicted probability of 0.3 means a 30% chance of default.

# %% [markdown]
# Hint 1: Preprocess your data
# We discussed standardizing/normalizing and simple transformations like polynomial features. The sklearn documentation can be a good starting point for further reading.
#
# Hint 2: Probabilistic classifiers
# Most of the classifiers in sklearn can be used to predict probabilities by using predict_proba() instead of predict().

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer



from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import brier_score_loss

# %%
df = pd.read_csv('/content/Loan_default.csv')

# %%
df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0                    4         15.23        36      0.44   Bachelor's
# 1                    1          4.81        60      0.68     Master's
# 2                    3         21.17        24      0.31     Master's
# 3                    3          7.07        24      0.23  High School
# 4                    4          6.51        48      0.73   Bachelor's
# ...                ...           ...       ...       ...          ...
# 255342               4         14.11        12      0.85   Bachelor's
# 255343               2         11.55        24      0.21  High School
# 255344               3          5.29        60      0.50  High School
# 255345               1         20.90        48      0.44  High School
# 255346               2          6.73        12      0.48   Bachelor's
#
#        EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0           Full-time      Divorced         Yes           Yes       Other
# 1           Full-time       Married          No            No       Other
# 2          Unemployed      Divorced         Yes           Yes        Auto
# 3           Full-time       Married          No            No    Business
# 4          Unemployed      Divorced          No           Yes        Auto
# ...               ...           ...         ...           ...         ...
# 255342      Full-time       Married          No            No       Other
# 255343      Part-time      Divorced          No            No        Home
# 255344  Self-employed       Married         Yes           Yes        Auto
# 255345      Part-time        Single         Yes           Yes       Other
# 255346     Unemployed      Divorced         Yes            No   Education
#
#        HasCoSigner  Default
# 0              Yes        0
# 1              Yes        0
# 2               No        1
# 3               No        0
# 4               No        0
# ...            ...      ...
# 255342          No        0
# 255343          No        1
# 255344         Yes        0
# 255345          No        0
# 255346         Yes        0
#
# [255347 rows x 18 columns]

# %%
# train and test data
train_df = pd.read_csv('/content/train.csv')
test_df = pd.read_csv('/content/test.csv')

# %%
train_df.head()
# Out:
#    ID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   0   21   78304      168713          653              60               1
# 1   1   28   63751       84674          681              58               1
# 2   2   57   96676      167540          467              98               4
# 3   3   24   79289       61546          358              63               4
# 4   4   31   98586      232342          692              10               2
#
#    InterestRate  LoanTerm  DTIRatio    Education EmploymentType MaritalStatus  \
# 0          8.80        60      0.59  High School      Part-time        Single
# 1          4.91        48      0.21          PhD      Part-time       Married
# 2         16.78        36      0.63  High School     Unemployed        Single
# 3          6.40        60      0.83     Master's      Full-time        Single
# 4         19.97        60      0.51          PhD     Unemployed       Married
#
#   HasMortgage HasDependents LoanPurpose HasCoSigner  Default
# 0          No           Yes        Home         Yes        0
# 1         Yes           Yes        Auto          No        0
# 2          No           Yes    Business         Yes        0
# 3         Yes           Yes    Business         Yes        0
# 4         Yes           Yes   Education         Yes        0

# %%
test_df.head()
# Out:
#        ID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  150000   62  131102      240256          538              17
# 1  150001   23   35766       97204          812              38
# 2  150002   61   28925       89471          381              81
# 3  150003   54   32569       28820          562              96
# 4  150004   41  136460      213437          558              80
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               1          7.13        60      0.82          PhD
# 1               4         12.50        12      0.84  High School
# 2               1          2.43        36      0.20     Master's
# 3               4          5.80        48      0.75   Bachelor's
# 4               3         13.76        36      0.21   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0  Self-employed        Single          No            No        Home
# 1      Part-time       Married          No            No   Education
# 2      Part-time        Single         Yes           Yes        Home
# 3      Full-time        Single         Yes           Yes        Auto
# 4      Full-time        Single          No            No   Education
#
#   HasCoSigner
# 0          No
# 1          No
# 2         Yes
# 3         Yes
# 4         Yes

# %%
# assigning features and target from training data
X = train_df.drop(['ID', 'Default'], axis=1)
y = train_df['Default']

# %% [markdown]
# Preprocessing:
# remember: Hint 1: Preprocess your data We discussed standardizing/normalizing and simple transformations like polynomial features. The sklearn documentation can be a good starting point for further reading.

# %%
# preprocessing for numerical data
# missing values will be replaced with column median and then standardizing
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# Preprocess categorical:
#missing values replaced with most frequent and then one-hot encoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]),
        ('cat', categorical_transformer, [cname for cname in X.columns if X[cname].dtype == 'object'])])

# %% [markdown]
# so first model choice is random forest since i think this is what makes the most sense when trying to find out at what level someone will repay their loan

# %%
model = RandomForestClassifier(n_estimators=250, random_state=0) # I changed n_estimators from 100 to 300 and now at 250

# %% [markdown]
# Hint 2: Probabilistic classifiers Most of the classifiers in sklearn can be used to predict probabilities by using predict_proba() instead of predict().

# %%
#pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', model)])

# splitting data into training and validation
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

#fitting
clf.fit(X_train, y_train)

#predictions
preds = clf.predict_proba(X_valid)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-a00aff601a66> in <cell line: 9>()
#       7
#       8 #fitting
# ----> 9 clf.fit(X_train, y_train)
#      10
#      11 #predictions
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     403             if self._final_estimator != "passthrough":
#     404                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     406
#     407         return self
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     728             for k, arg in zip(sig.parameters, args):
#     729                 kwargs[k] = arg
# --> 730             return func(**kwargs)
#     731
#     732         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1517             )
#    1518
# -> 1519             self._Booster = train(
#    1520                 params,
#    1521                 train_dmatrix,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     728             for k, arg in zip(sig.parameters, args):
#     729                 kwargs[k] = arg
# --> 730             return func(**kwargs)
#     731
#     732         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     180             break
#     181         bst.update(dtrain, i, obj)
# --> 182         if cb_container.after_iteration(bst, i, dtrain, evals):
#     183             break
#     184
#
# /usr/local/lib/python3.10/dist-packages/xgboost/callback.py in after_iteration(self, model, epoch, dtrain, evals)
#     239             metric_score = _parse_eval_str(score)
#     240             self._update_history(metric_score, epoch)
# --> 241         ret = any(c.after_iteration(model, epoch, self.history) for c in self.callbacks)
#     242         return ret
#     243
#
# /usr/local/lib/python3.10/dist-packages/xgboost/callback.py in <genexpr>(.0)
#     239             metric_score = _parse_eval_str(score)
#     240             self._update_history(metric_score, epoch)
# --> 241         ret = any(c.after_iteration(model, epoch, self.history) for c in self.callbacks)
#     242         return ret
#     243
#
# /usr/local/lib/python3.10/dist-packages/xgboost/callback.py in after_iteration(self, model, epoch, evals_log)
#     424         msg = "Must have at least 1 validation dataset for early stopping."
#     425         if len(evals_log.keys()) < 1:
# --> 426             raise ValueError(msg)
#     427
#     428         # Get data name
#
# ValueError: Must have at least 1 validation dataset for early stopping.

# %%
# model eval
print('Brier score:', brier_score_loss(y_valid, preds))
# Out:
# Brier score: 0.11438821592592592

# %%
# test data, fit model
preds_test = clf.predict_proba(test_df.drop(['ID'], axis=1))[:, 1]

output = pd.DataFrame({'ID': test_df.ID,
                       'TARGET': preds_test})

# %%
output
# Out:
#            ID    TARGET
# 0      150000  0.156667
# 1      150001  0.290000
# 2      150002  0.130000
# 3      150003  0.066667
# 4      150004  0.040000
# ...       ...       ...
# 49995  199995  0.130000
# 49996  199996  0.326667
# 49997  199997  0.050000
# 49998  199998  0.250000
# 49999  199999  0.106667
#
# [50000 rows x 2 columns]

# %%
# Save test predictions to file
output = pd.DataFrame({'ID': test_df.ID,
                       'TARGET': preds_test})
output.to_csv('cecily_wang_submission.csv', index=False)

# %% [markdown]
# # part 2 (using grid search to see if i can better accuracy)

# %% [markdown]
# Trying to get better score. grid search

# %% [markdown]
# #I changed n estimators from 10,15,35 to 15,75,125 to try and see if i could get a better score. Wjith the first round of using Grid search, it got me a submission score of .11417. And previous to that without using grid search (the code above) i was able to get .11445.

# %%
# Define a grid of hyperparameter ranges
param_grid = {
    'model__n_estimators': [15, 75, 130],
    'model__max_depth': [5, 10, None],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

# %%
#grid search object
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=4, scoring='neg_brier_score', verbose=2, n_jobs=-1)

#fitting to data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 81 candidates, totalling 324 fits

# %%
print("Best parameters:", grid_search.best_params_)

# %% [markdown]
# ## it makes sense the the model n estimators chosen was 125 which makes me wonder if I were to do this again, if I were to put in parameter that would be closer to 100 or closer to 150 next time

# %%
# here using the best estimator to make predictions
best_clf = grid_search.best_estimator_
preds = best_clf.predict_proba(X_valid)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a588615c59f4> in <cell line: 2>()
#       1 # here using the best estimator to make predictions
# ----> 2 best_clf = grid_search.best_estimator_
#       3 preds = best_clf.predict_proba(X_valid)[:, 1]
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
#eval
print('Brier score of the best model:', brier_score_loss(y_valid, preds))
# Out:
# Brier score of the best model: 0.11417937413894808

# %%
preds_test = best_clf.predict_proba(test_df.drop(['ID'], axis=1))[:, 1]

# %%
output2 = pd.DataFrame({'ID': test_df.ID, 'TARGET': preds_test})

# %%
output2.to_csv('2submission.csv', index=False)

# %% [markdown]
# # part three trying to vget a better score

# %%
# Define a grid of hyperparameter ranges
param_grid = {
    'model__n_estimators': [25, 100, 130],
    'model__max_depth': [5, 10, None],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

# %%
#grid search object
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, scoring='neg_brier_score', verbose=2, n_jobs=-1)

# %%
#fitting to data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-a26f789c3ba9> in <cell line: 2>()
#       1 #fitting to data
# ----> 2 grid_search.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1760                 (self._jobs[0].get_status(
#    1761                     timeout=self.timeout) == TASK_PENDING)):
# -> 1762                 time.sleep(0.01)
#    1763                 continue
#    1764
#
# KeyboardInterrupt:

# %%
print("Best parameters:", grid_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ba4805b09025> in <cell line: 1>()
# ----> 1 print("Best parameters:", grid_search.best_params_)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
# here using the best estimator to make predictions
best_clf = grid_search.best_estimator_
preds = best_clf.predict_proba(X_valid)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-a588615c59f4> in <cell line: 2>()
#       1 # here using the best estimator to make predictions
# ----> 2 best_clf = grid_search.best_estimator_
#       3 preds = best_clf.predict_proba(X_valid)[:, 1]
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
#eval
print('Brier score of the best model:', brier_score_loss(y_valid, preds))
# Out:
# Brier score of the best model: 0.11417937413894808

# %%
preds_test = best_clf.predict_proba(test_df.drop(['ID'], axis=1))[:, 1]

# %% [markdown]
# ### Part 4

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier


# Define a larger grid of hyperparameters to explore
param_grid = {
    'model__n_estimators': [15,75 , 135],
    'model__max_depth': [5, 15, 25, None],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4],
    'model__max_features': ['auto', 'sqrt'],
    'model__bootstrap': [True, False]
}

# adding SimpleImputer() to numerical and categorical transformers

model = RandomForestClassifier(random_state=0)

# pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', model)])

# randomized search to sample from the param_grid
random_search = RandomizedSearchCV(
    estimator=clf,
    param_distributions=param_grid,
    n_iter=100,  # number of parameter settings that are sampled
    cv=5,
    scoring='neg_brier_score',
    verbose=2,
    random_state=0,
    n_jobs=-1
)

# fit random search model
random_search.fit(X_train, y_train)

# best model
best_clf = random_search.best_estimator_

# predictions on the validation set
preds = best_clf.predict_proba(X_valid)[:, 1]

print('Brier score of the best model:', brier_score_loss(y_valid, preds))

# predictions on test set
preds_test = best_clf.predict_proba(test_df.drop(['ID'], axis=1))[:, 1]
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-ed736f8f4289> in <cell line: 47>()
#      45 preds = best_clf.predict_proba(X_valid)[:, 1]
#      46
# ---> 47 print('Brier score of the best model:', brier_score_loss(y_valid, preds))
#      48
#      49 # predictions on test set
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in brier_score_loss(y_true, y_prob, sample_weight, pos_label)
#    2873     y_true = column_or_1d(y_true)
#    2874     y_prob = column_or_1d(y_prob)
# -> 2875     assert_all_finite(y_true)
#    2876     assert_all_finite(y_prob)
#    2877     check_consistent_length(y_true, y_prob, sample_weight)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in assert_all_finite(X, allow_nan, estimator_name, input_name)
#     188         documentation.
#     189     """
# --> 190     _assert_all_finite(
#     191         X.data if sp.issparse(X) else X,
#     192         allow_nan=allow_nan,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     159                 "#estimators-that-handle-nan-values"
#     160             )
# --> 161         raise ValueError(msg_err)
#     162
#     163
#
# ValueError: Input contains NaN.

# %%
# Save test predictions to file
output = pd.DataFrame({'ID': test_df.ID,
                       'TARGET': preds_test})
output.to_csv('3submission.csv', index=False)

# %% [markdown]
# Explanation and work through of my code:

# %% [markdown]
# ok so doing the grid search with param: 'model__n_estimators': [15, 75, 125] helped greatly improve my score in comparison to the other two

# %% [markdown]
# first I immediately thought of decision trees and random forests for the problem since we were trying to find a certain 'threshold' that could evaluate the loan repayment. Decision trees in this problem would be good to handle the non-linear relationships and interactions between the multiple features. But, I decided to first use scikit RandomForestClassifier so i could potentially fight against overfitting, especially given the complexity and potential noise in the dataset.
#
# as for the parameter tuning, I did gridsearchCV to optimize the RandomForest parameters. Here I did two rounds on the parameters: n_estimators, max_depth, and min_samples_split. This helped mefind the best combination of parameters that would minimize overfitting while maximizing the model's predictive accuracy. It took about 7 minutes for this part of the code to run each time due to the large nature of the data but this is where I was able to heavily improve my accuracy. I alos think that the best part that I was able to implement into this process was the preprocessing pipeline (imputation, scaling, and encoding steps tailored to different data types). This also improved my model performance by ensuring that the model received clean and well-structured input data. The one-hot encoding for categorical variables and standard scaling for numerical inputs also helped in normalizing the feature scales and handling categorical data effectively. I will say that it was quite difficult making sure that the preprocessing steps were correctly applied during both training and prediction phases. Initially, discrepancies in handling missing values and categorical variables between the training and testing phases led to inconsistencies in model performance but once i was able to figure this out I could fix the issues by tightly integrating the preprocessing steps into the pipeline which made sure that the data transformations were applied correctly.
#
# to bring it up again, the main issue that I still wish I could fix was the increased computational cost and time associated with training, especially the parameter tuning with grid search. Despite this, the trade-off with being able to heaivly improve predictive accuracy and model robustness against overfitting was ok.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import brier_score_loss
from xgboost import XGBClassifier

df = pd.read_csv('/content/Loan_default.csv')

train_df = pd.read_csv('/content/train.csv')
test_df = pd.read_csv('/content/test.csv')

X = train_df.drop(['ID', 'Default'], axis=1)
y = train_df['Default']

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]),
        ('cat', categorical_transformer, [cname for cname in X.columns if X[cname].dtype == 'object'])])

model = XGBClassifier(n_estimators=24, random_state=0, use_label_encoder=False, eval_metric='logloss')

clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', model)])

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

clf.fit(X_train, y_train)

preds = clf.predict_proba(X_valid)[:, 1]

print('Brier score:', brier_score_loss(y_valid, preds))

preds_test = clf.predict_proba(test_df.drop(['ID'], axis=1))[:, 1]
output = pd.DataFrame({'ID': test_df.ID, 'TARGET': preds_test})
# Out:
# Brier score: 0.11320250487632796

# %%
output = pd.DataFrame({'ID': test_df.ID,
                       'TARGET': preds_test})
output.to_csv('9cecily_wang_submission.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import brier_score_loss
from xgboost import XGBClassifier


numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(transformers=[
    ('num', numerical_transformer, [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]),
    ('cat', categorical_transformer, [cname for cname in X.columns if X[cname].dtype == 'object'])])

#classifier with early stopping
model = XGBClassifier(
    n_estimators=555,
    max_depth=5,
    learning_rate=0.04,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=0.1,
    random_state=0,
    use_label_encoder=False,
    eval_metric='logloss',
    enable_categorical=True,
    early_stopping_rounds=10
)

# Preprocess
X_preprocessed = preprocessor.fit_transform(X)
X_train, X_valid, y_train, y_valid = train_test_split(X_preprocessed, y, train_size=0.75, test_size=0.15, random_state=0)

#  XGBClassifier
model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])

preds = model.predict_proba(X_valid)[:, 1]
print('Brier score:', brier_score_loss(y_valid, preds))

X_test_preprocessed = preprocessor.transform(test_df.drop(['ID'], axis=1))
preds_test = model.predict_proba(X_test_preprocessed)[:, 1]
output = pd.DataFrame({'ID': test_df['ID'], 'TARGET': preds_test})
# Out:
# [0]	validation_0-logloss:0.43806
# [1]	validation_0-logloss:0.43473
# [2]	validation_0-logloss:0.43230
# [3]	validation_0-logloss:0.42934
# [4]	validation_0-logloss:0.42660
# [5]	validation_0-logloss:0.42408
# [6]	validation_0-logloss:0.42171
# [7]	validation_0-logloss:0.42011
# [8]	validation_0-logloss:0.41799
# [9]	validation_0-logloss:0.41596
# [10]	validation_0-logloss:0.41429
# [11]	validation_0-logloss:0.41265
# [12]	validation_0-logloss:0.41119
# [13]	validation_0-logloss:0.40976
# [14]	validation_0-logloss:0.40828
# [15]	validation_0-logloss:0.40690
# [16]	validation_0-logloss:0.40586
# [17]	validation_0-logloss:0.40461
# [18]	validation_0-logloss:0.40345
# [19]	validation_0-logloss:0.40251
# [20]	validation_0-logloss:0.40155
# [21]	validation_0-logloss:0.40047
# [22]	validation_0-logloss:0.39943
# [23]	validation_0-logloss:0.39858
# [24]	validation_0-logloss:0.39773
# [25]	validation_0-logloss:0.39687
# [26]	validation_0-logloss:0.39625
# [27]	validation_0-logloss:0.39545
# [28]	validation_0-logloss:0.39468
# [29]	validation_0-logloss:0.39403
# [30]	validation_0-logloss:0.39333
# [31]	validation_0-logloss:0.39266
# [32]	validation_0-logloss:0.39192
# [33]	validation_0-logloss:0.39121
# [34]	validation_0-logloss:0.39062
# [35]	validation_0-logloss:0.39002
# [36]	validation_0-logloss:0.38947
# [37]	validation_0-logloss:0.38892
# [38]	validation_0-logloss:0.38850
# [39]	validation_0-logloss:0.38802
# [40]	validation_0-logloss:0.38753
# [41]	validation_0-logloss:0.38704
# [42]	validation_0-logloss:0.38662
# [43]	validation_0-logloss:0.38619
# [44]	validation_0-logloss:0.38577
# [45]	validation_0-logloss:0.38543
# [46]	validation_0-logloss:0.38504
# [47]	validation_0-logloss:0.38464
# [48]	validation_0-logloss:0.38430
# [49]	validation_0-logloss:0.38391
# [50]	validation_0-logloss:0.38354
# [51]	validation_0-logloss:0.38318
# [52]	validation_0-logloss:0.38290
# [53]	validation_0-logloss:0.38263
# [54]	validation_0-logloss:0.38233
# [55]	validation_0-logloss:0.38199
# [56]	validation_0-logloss:0.38171
# [57]	validation_0-logloss:0.38144
# [58]	validation_0-logloss:0.38113
# [59]	validation_0-logloss:0.38088
# [60]	validation_0-logloss:0.38061
# [61]	validation_0-logloss:0.38037
# [62]	validation_0-logloss:0.38015
# [63]	validation_0-logloss:0.37990
# [64]	validation_0-logloss:0.37964
# [65]	validation_0-logloss:0.37941
# [66]	validation_0-logloss:0.37921
# [67]	validation_0-logloss:0.37897
# [68]	validation_0-logloss:0.37879
# [69]	validation_0-logloss:0.37858
# [70]	validation_0-logloss:0.37839
# [71]	validation_0-logloss:0.37812
# [72]	validation_0-logloss:0.37786
# [73]	validation_0-logloss:0.37768
# [74]	validation_0-logloss:0.37748
# [75]	validation_0-logloss:0.37733
# [76]	validation_0-logloss:0.37712
# [77]	validation_0-logloss:0.37693
# [78]	validation_0-logloss:0.37677
# [79]	validation_0-logloss:0.37658
# [80]	validation_0-logloss:0.37638
# [81]	validation_0-logloss:0.37621
# [82]	validation_0-logloss:0.37598
# [83]	validation_0-logloss:0.37586
# [84]	validation_0-logloss:0.37571
# [85]	validation_0-logloss:0.37547
# [86]	validation_0-logloss:0.37533
# [87]	validation_0-logloss:0.37519
# [88]	validation_0-logloss:0.37509
# [89]	validation_0-logloss:0.37495
# [90]	validation_0-logloss:0.37481
# [91]	validation_0-logloss:0.37473
# [92]	validation_0-logloss:0.37449
# [93]	validation_0-logloss:0.37434
# [94]	validation_0-logloss:0.37423
# [95]	validation_0-logloss:0.37412
# [96]	validation_0-logloss:0.37401
# [97]	validation_0-logloss:0.37390
# [98]	validation_0-logloss:0.37379
# [99]	validation_0-logloss:0.37363
# [100]	validation_0-logloss:0.37353
# [101]	validation_0-logloss:0.37343
# [102]	validation_0-logloss:0.37333
# [103]	validation_0-logloss:0.37322
# [104]	validation_0-logloss:0.37312
# [105]	validation_0-logloss:0.37302
# [106]	validation_0-logloss:0.37288
# [107]	validation_0-logloss:0.37274
# [108]	validation_0-logloss:0.37264
# [109]	validation_0-logloss:0.37259
# [110]	validation_0-logloss:0.37250
# [111]	validation_0-logloss:0.37241
# [112]	validation_0-logloss:0.37234
# [113]	validation_0-logloss:0.37220
# [114]	validation_0-logloss:0.37208
# [115]	validation_0-logloss:0.37202
# [116]	validation_0-logloss:0.37194
# [117]	validation_0-logloss:0.37183
# [118]	validation_0-logloss:0.37172
# [119]	validation_0-logloss:0.37157
# [120]	validation_0-logloss:0.37147
# [121]	validation_0-logloss:0.37138
# [122]	validation_0-logloss:0.37127
# [123]	validation_0-logloss:0.37123
# [124]	validation_0-logloss:0.37119
# [125]	validation_0-logloss:0.37106
# [126]	validation_0-logloss:0.37099
# [127]	validation_0-logloss:0.37090
# [128]	validation_0-logloss:0.37082
# [129]	validation_0-logloss:0.37077
# [130]	validation_0-logloss:0.37069
# [131]	validation_0-logloss:0.37060
# [132]	validation_0-logloss:0.37054
# [133]	validation_0-logloss:0.37046
# [134]	validation_0-logloss:0.37042
# [135]	validation_0-logloss:0.37033
# [136]	validation_0-logloss:0.37027
# [137]	validation_0-logloss:0.37022
# [138]	validation_0-logloss:0.37015
# [139]	validation_0-logloss:0.37012
# [140]	validation_0-logloss:0.37008
# [141]	validation_0-logloss:0.37002
# [142]	validation_0-logloss:0.36997
# [143]	validation_0-logloss:0.36988
# [144]	validation_0-logloss:0.36979
# [145]	validation_0-logloss:0.36968
# [146]	validation_0-logloss:0.36963
# [147]	validation_0-logloss:0.36960
# [148]	validation_0-logloss:0.36956
# [149]	validation_0-logloss:0.36949
# [150]	validation_0-logloss:0.36941
# [151]	validation_0-logloss:0.36933
# [152]	validation_0-logloss:0.36927
# [153]	validation_0-logloss:0.36924
# [154]	validation_0-logloss:0.36912
# [155]	validation_0-logloss:0.36902
# [156]	validation_0-logloss:0.36900
# [157]	validation_0-logloss:0.36890
# [158]	validation_0-logloss:0.36881
# [159]	validation_0-logloss:0.36874
# [160]	validation_0-logloss:0.36868
# [161]	validation_0-logloss:0.36862
# [162]	validation_0-logloss:0.36860
# [163]	validation_0-logloss:0.36855
# [164]	validation_0-logloss:0.36852
# [165]	validation_0-logloss:0.36844
# [166]	validation_0-logloss:0.36841
# [167]	validation_0-logloss:0.36836
# [168]	validation_0-logloss:0.36832
# [169]	validation_0-logloss:0.36824
# [170]	validation_0-logloss:0.36819
# [171]	validation_0-logloss:0.36816
# [172]	validation_0-logloss:0.36810
# [173]	validation_0-logloss:0.36810
# [174]	validation_0-logloss:0.36805
# [175]	validation_0-logloss:0.36803
# [176]	validation_0-logloss:0.36798
# [177]	validation_0-logloss:0.36792
# [178]	validation_0-logloss:0.36789
# [179]	validation_0-logloss:0.36783
# [180]	validation_0-logloss:0.36778
# [181]	validation_0-logloss:0.36773
# [182]	validation_0-logloss:0.36764
# [183]	validation_0-logloss:0.36763
# [184]	validation_0-logloss:0.36760
# [185]	validation_0-logloss:0.36757
# [186]	validation_0-logloss:0.36754
# [187]	validation_0-logloss:0.36751
# [188]	validation_0-logloss:0.36750
# [189]	validation_0-logloss:0.36745
# [190]	validation_0-logloss:0.36737
# [191]	validation_0-logloss:0.36728
# [192]	validation_0-logloss:0.36724
# [193]	validation_0-logloss:0.36720
# [194]	validation_0-logloss:0.36714
# [195]	validation_0-logloss:0.36708
# [196]	validation_0-logloss:0.36705
# [197]	validation_0-logloss:0.36701
# [198]	validation_0-logloss:0.36699
# [199]	validation_0-logloss:0.36690
# [200]	validation_0-logloss:0.36687
# [201]	validation_0-logloss:0.36682
# [202]	validation_0-logloss:0.36679
# [203]	validation_0-logloss:0.36676
# [204]	validation_0-logloss:0.36674
# [205]	validation_0-logloss:0.36672
# [206]	validation_0-logloss:0.36667
# [207]	validation_0-logloss:0.36663
# [208]	validation_0-logloss:0.36661
# [209]	validation_0-logloss:0.36657
# [210]	validation_0-logloss:0.36652
# [211]	validation_0-logloss:0.36649
# [212]	validation_0-logloss:0.36645
# [213]	validation_0-logloss:0.36643
# [214]	validation_0-logloss:0.36642
# [215]	validation_0-logloss:0.36640
# [216]	validation_0-logloss:0.36636
# [217]	validation_0-logloss:0.36631
# [218]	validation_0-logloss:0.36630
# [219]	validation_0-logloss:0.36626
# [220]	validation_0-logloss:0.36627
# [221]	validation_0-logloss:0.36620
# [222]	validation_0-logloss:0.36615
# [223]	validation_0-logloss:0.36611
# [224]	validation_0-logloss:0.36609
# [225]	validation_0-logloss:0.36604
# [226]	validation_0-logloss:0.36603
# [227]	validation_0-logloss:0.36599
# [228]	validation_0-logloss:0.36597
# [229]	validation_0-logloss:0.36594
# [230]	validation_0-logloss:0.36593
# [231]	validation_0-logloss:0.36591
# [232]	validation_0-logloss:0.36588
# [233]	validation_0-logloss:0.36586
# [234]	validation_0-logloss:0.36586
# [235]	validation_0-logloss:0.36585
# [236]	validation_0-logloss:0.36581
# [237]	validation_0-logloss:0.36582
# [238]	validation_0-logloss:0.36580
# [239]	validation_0-logloss:0.36577
# [240]	validation_0-logloss:0.36574
# [241]	validation_0-logloss:0.36571
# [242]	validation_0-logloss:0.36570
# [243]	validation_0-logloss:0.36567
# [244]	validation_0-logloss:0.36564
# [245]	validation_0-logloss:0.36561
# [246]	validation_0-logloss:0.36557
# [247]	validation_0-logloss:0.36554
# [248]	validation_0-logloss:0.36552
# [249]	validation_0-logloss:0.36551
# [250]	validation_0-logloss:0.36549
# [251]	validation_0-logloss:0.36546
# [252]	validation_0-logloss:0.36545
# [253]	validation_0-logloss:0.36542
# [254]	validation_0-logloss:0.36539
# [255]	validation_0-logloss:0.36535
# [256]	validation_0-logloss:0.36532
# [257]	validation_0-logloss:0.36528
# [258]	validation_0-logloss:0.36524
# [259]	validation_0-logloss:0.36522
# [260]	validation_0-logloss:0.36522
# [261]	validation_0-logloss:0.36518
# [262]	validation_0-logloss:0.36518
# [263]	validation_0-logloss:0.36516
# [264]	validation_0-logloss:0.36512
# [265]	validation_0-logloss:0.36511
# [266]	validation_0-logloss:0.36509
# [267]	validation_0-logloss:0.36508
# [268]	validation_0-logloss:0.36504
# [269]	validation_0-logloss:0.36502
# [270]	validation_0-logloss:0.36498
# [271]	validation_0-logloss:0.36496
# [272]	validation_0-logloss:0.36495
# [273]	validation_0-logloss:0.36494
# [274]	validation_0-logloss:0.36495
# [275]	validation_0-logloss:0.36493
# [276]	validation_0-logloss:0.36490
# [277]	validation_0-logloss:0.36489
# [278]	validation_0-logloss:0.36485
# [279]	validation_0-logloss:0.36482
# [280]	validation_0-logloss:0.36481
# [281]	validation_0-logloss:0.36477
# [282]	validation_0-logloss:0.36477
# [283]	validation_0-logloss:0.36475
# [284]	validation_0-logloss:0.36474
# [285]	validation_0-logloss:0.36472
# [286]	validation_0-logloss:0.36469
# [287]	validation_0-logloss:0.36467
# [288]	validation_0-logloss:0.36466
# [289]	validation_0-logloss:0.36464
# [290]	validation_0-logloss:0.36463
# [291]	validation_0-logloss:0.36461
# [292]	validation_0-logloss:0.36461
# [293]	validation_0-logloss:0.36459
# [294]	validation_0-logloss:0.36458
# [295]	validation_0-logloss:0.36458
# [296]	validation_0-logloss:0.36456
# [297]	validation_0-logloss:0.36455
# [298]	validation_0-logloss:0.36451
# [299]	validation_0-logloss:0.36450
# [300]	validation_0-logloss:0.36449
# [301]	validation_0-logloss:0.36446
# [302]	validation_0-logloss:0.36444
# [303]	validation_0-logloss:0.36442
# [304]	validation_0-logloss:0.36442
# [305]	validation_0-logloss:0.36438
# [306]	validation_0-logloss:0.36437
# [307]	validation_0-logloss:0.36437
# [308]	validation_0-logloss:0.36437
# [309]	validation_0-logloss:0.36436
# [310]	validation_0-logloss:0.36437
# [311]	validation_0-logloss:0.36437
# [312]	validation_0-logloss:0.36434
# [313]	validation_0-logloss:0.36431
# [314]	validation_0-logloss:0.36427
# [315]	validation_0-logloss:0.36427
# [316]	validation_0-logloss:0.36427
# [317]	validation_0-logloss:0.36425
# [318]	validation_0-logloss:0.36425
# [319]	validation_0-logloss:0.36425
# [320]	validation_0-logloss:0.36425
# [321]	validation_0-logloss:0.36425
# [322]	validation_0-logloss:0.36421
# [323]	validation_0-logloss:0.36421
# [324]	validation_0-logloss:0.36419
# [325]	validation_0-logloss:0.36417
# [326]	validation_0-logloss:0.36418
# [327]	validation_0-logloss:0.36416
# [328]	validation_0-logloss:0.36416
# [329]	validation_0-logloss:0.36414
# [330]	validation_0-logloss:0.36411
# [331]	validation_0-logloss:0.36411
# [332]	validation_0-logloss:0.36411
# [333]	validation_0-logloss:0.36413
# [334]	validation_0-logloss:0.36411
# [335]	validation_0-logloss:0.36410
# [336]	validation_0-logloss:0.36408
# [337]	validation_0-logloss:0.36406
# [338]	validation_0-logloss:0.36405
# [339]	validation_0-logloss:0.36403
# [340]	validation_0-logloss:0.36401
# [341]	validation_0-logloss:0.36400
# [342]	validation_0-logloss:0.36399
# [343]	validation_0-logloss:0.36399
# [344]	validation_0-logloss:0.36396
# [345]	validation_0-logloss:0.36397
# [346]	validation_0-logloss:0.36397
# [347]	validation_0-logloss:0.36395
# [348]	validation_0-logloss:0.36394
# [349]	validation_0-logloss:0.36394
# [350]	validation_0-logloss:0.36394
# [351]	validation_0-logloss:0.36394
# [352]	validation_0-logloss:0.36393
# [353]	validation_0-logloss:0.36395
# [354]	validation_0-logloss:0.36393
# [355]	validation_0-logloss:0.36390
# [356]	validation_0-logloss:0.36388
# [357]	validation_0-logloss:0.36386
# [358]	validation_0-logloss:0.36387
# [359]	validation_0-logloss:0.36386
# [360]	validation_0-logloss:0.36383
# [361]	validation_0-logloss:0.36381
# [362]	validation_0-logloss:0.36380
# [363]	validation_0-logloss:0.36379
# [364]	validation_0-logloss:0.36379
# [365]	validation_0-logloss:0.36379
# [366]	validation_0-logloss:0.36380
# [367]	validation_0-logloss:0.36379
# [368]	validation_0-logloss:0.36378
# [369]	validation_0-logloss:0.36380
# [370]	validation_0-logloss:0.36380
# [371]	validation_0-logloss:0.36378
# [372]	validation_0-logloss:0.36377
# [373]	validation_0-logloss:0.36376
# [374]	validation_0-logloss:0.36375
# [375]	validation_0-logloss:0.36374
# [376]	validation_0-logloss:0.36373
# [377]	validation_0-logloss:0.36373
# [378]	validation_0-logloss:0.36374
# [379]	validation_0-logloss:0.36371
# [380]	validation_0-logloss:0.36369
# [381]	validation_0-logloss:0.36368
# [382]	validation_0-logloss:0.36365
# [383]	validation_0-logloss:0.36365
# [384]	validation_0-logloss:0.36362
# [385]	validation_0-logloss:0.36363
# [386]	validation_0-logloss:0.36364
# [387]	validation_0-logloss:0.36363
# [388]	validation_0-logloss:0.36362
# [389]	validation_0-logloss:0.36363
# [390]	validation_0-logloss:0.36361
# [391]	validation_0-logloss:0.36359
# [392]	validation_0-logloss:0.36360
# [393]	validation_0-logloss:0.36359
# [394]	validation_0-logloss:0.36360
# [395]	validation_0-logloss:0.36359
# [396]	validation_0-logloss:0.36358
# [397]	validation_0-logloss:0.36357
# [398]	validation_0-logloss:0.36358
# [399]	validation_0-logloss:0.36355
# [400]	validation_0-logloss:0.36354
# [401]	validation_0-logloss:0.36353
# [402]	validation_0-logloss:0.36354
# [403]	validation_0-logloss:0.36354
# [404]	validation_0-logloss:0.36354
# [405]	validation_0-logloss:0.36355
# [406]	validation_0-logloss:0.36354
# [407]	validation_0-logloss:0.36355
# [408]	validation_0-logloss:0.36355
# [409]	validation_0-logloss:0.36354
# [410]	validation_0-logloss:0.36353
# [411]	validation_0-logloss:0.36354
# Brier score: 0.1112067994381308

# %%
from sklearn.metrics import make_scorer, brier_score_loss


train_df = pd.read_csv('/content/train.csv')
test_df = pd.read_csv('/content/test.csv')

X = train_df.drop(['ID', 'Default'], axis=1)
y = train_df['Default']
X_test = test_df.drop(['ID'], axis=1)

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(transformers=[
    ('num', numerical_transformer, [cname for cname in X.columns if X[cname].dtype in ['int64', 'float64']]),
    ('cat', categorical_transformer, [cname for cname in X.columns if X[cname].dtype == 'object'])])

full_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(
        n_estimators=1100,
        max_depth=5,
        learning_rate=0.03,
        subsample=0.6,
        colsample_bytree=0.8,
        reg_alpha=0.7,
        reg_lambda=0.7,
        random_state=0,
        use_label_encoder=False,
        eval_metric='logloss',
        enable_categorical=True))
])

brier_scorer = make_scorer(brier_score_loss, needs_proba=True, greater_is_better=False)

# k-fold cross-validation
scores = cross_val_score(full_pipeline, X, y, cv=5, scoring=brier_scorer)

print("Cross-validated Brier scores:", scores)
print("Mean Brier score:", -scores.mean())
# Out:
# Cross-validated Brier scores: [-0.10928798 -0.10899046 -0.10944336 -0.10891281 -0.10917109]
# Mean Brier score: 0.10916114086867942

# %%
# full pipeline on all training data
full_pipeline.fit(X, y)

# Predict test set
test_predictions = full_pipeline.predict_proba(X_test)[:, 1]

test_output = pd.DataFrame({'ID': test_df['ID'], 'TARGET': test_predictions})

# %%
test_output.to_csv('37cecily_wang_submission.csv', index=False)

# %% [markdown]
# # ok this part is a resubmission since I got better scores throughout the week. I was stuck initially on the previous model and so I decided to incoporate XGboosting into my model. I initially tried to do more gridsearch but it alwaysss took so long to load and so I just ran the code over and over with differing parameters and I landed on this submission (37) model as the best one. The part that I adjusted the most were n_estimators, learning rate, and I increased alpha and lambda.

# %% [markdown]
# #jlajdlfjae;

# %%
#nKLFv;JOf

# %% [markdown]
# # ajjdlfak

# %%
#jafjdsljlfa

# %% [markdown]
# # ajlf

# %%
jfaik;fja
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-82383667e92c> in <cell line: 1>()
# ----> 1 jfaik;fja
#
# NameError: name 'jfaik' is not defined

# %% [markdown]
# #33 fojaldfal

# %% [markdown]
# # ajlfjald

# %% [markdown]
# jafFDLjal.

# %% [markdown]
# :ADSJfla

# %% [markdown]
# #aklfjl;akf ;fewal

# %% [markdown]
# # aklfjfdlafj;

# %%
#jfa

# %% [markdown]
# #fjladjslkas

# %% [markdown]
# #raejfldfa;

# %% [markdown]
# #jfalj;fda'

# %% [markdown]
# #fkalj;afgj

# %% [markdown]
# # fjfal

# %%
dksalfdsa

# %%
dsalkf;da

# %%
jfal;jfdladjak;w

# %%
lj;ljf;lkdj;laf

# %%
fadlsk;jfla

# %%
ifadsjilas;hkfla

# %%
jfedal;jfal
